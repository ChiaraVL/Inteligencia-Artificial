# %% [markdown]
# <p align="center">
# <FONT FACE="times new roman" SIZE=5>
# <br>
# <img src="https://res-5.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco/v1455514364/pim02bzqvgz0hibsra41.png"
# width="250" height="250">
# </img>
# <br>
# <i><b>Docente:</b> Juan Pablo Ospina Lopez.</i>
# <br>
# <i><b>Asignatura:</b> Inteligencia Artificial</i>
# <br>
# <i><b>Estudiante:</b> Chiara Valenzuela</i>
# <br>
# <i><b>Tema:</b> Laboratorio 1. Agentes Inteligentes</i>
# <br>
# <i>17/08/23</i>
# </FONT>
# </p>

# %% [markdown]
# El siguiente laboratorio está relacionado con el proceso de solución de problemas en IA utilizando el concepto de agente. Para el desarrollo del laboratorio tenga en cuenta lo siguiente:
#
# * La actividad puede realizarse en grupos de máximo 3 personas
# * La solución del laboratorio debe enviarse en un notebook a través de Moodle. Se debe adjuntar el archivo. No se aceptan enlaces.
# * El uso del lenguaje matemático debe hacerse utilizando `LaTeX`
# * El objetivo del laboratorio es hacer énfasis en el proceso de modelamiento. Sea claro en sus respuestas
# * Si se detecta cualquier tipo de fraude, la calificación de 0.0.
# * El código implementado deben cumplir con las recomendaciones de código limpio especificadas en el [PEP8](https://pep8.org/), de lo contrario será penalizado
# _______________________________________

# %% [markdown]
# ####  __1. `(0.5 puntos)` Suponga que un agente selecciona su siguiente movimiento de manera aleatoria del conjunto de acciones posibles. Si todas las acciones tiene la misma probabilidad, ¿existe un problema en específico dónde el agente tenga un comportamiento racional? Justifique su respuesta.__

# %% [markdown]
# $\textrm{La elección de acciones mediante un proceso aleatorio y equiprobable por parte de un agente puede ser considerada una estrategia} \\ \textrm{racional en determinados contextos caracterizados por una ausencia de información discriminativa, lo que establece un fundamento } \\ \textrm{para este comportamiento.} \\ $
#
# $\textrm{Un ejemplo ilustrativo de esta racionalidad es el caso de un explorador quien se encuentra en una región desconocida del océano,} \\ \textrm{donde no tiene información sobre las corrientes, la geografía submarina ni la ubicación de los recursos. En este escenario, cualquier} \\ \textrm{dirección que el explorador elija carece de información justificativa, y todas las direcciones tienen igual probabilidad de llevar a un} \\ \textrm{descubrimiento interesante o a un callejón sin salida. En esta situación, el explorador podría decidir moverse en una dirección aleatoria} \\ \textrm{en busca de nuevas oportunidades.}$

# %% [markdown]
# #### __2. `(0.5 puntos)` Suponga que el comportamiento de un agente es evaluado a través de una métrica de desempeño que solo considera las primeras 𝑇 unidades de tiempo e ignora todo lo demás después de eso. Muestre que la racionalidad del agente no depende únicamente del estado del ambiente, sino del tiempo disponible. Presente 2 ejemplos para esta situación.__

# %% [markdown]
# $\textrm{La racionalidad de un agente se refiere a su capacidad para seleccionar acciones que maximicen su medida de rendimiento} \\ \textrm{esperado en función de su conocimiento y creencias actuales sobre el entorno. En situaciones donde la racionalidad del agente} \\ \textrm{depende no solo del estado del ambiente, sino también del tiempo disponible, se demuestra que el agente debe considerar la} \\ \textrm{limitación de tiempo en su toma de decisiones para maximizar su desempeño según la métrica dada. Esto se debe a que, en este} \\ \textrm{caso, el agente estaría incentivado a optimizar su desempeño en el período de tiempo relevante (primeras 𝑇 unidades de tiempo)} \\ \textrm{y puede que no le importe tanto el comportamiento o las consecuencias a largo plazo.} \\ $
#
# - **$\textrm{Ejemplo 1: Inversión a corto plazo en el mercado de valores:}$**
#
# >$\textrm{Supongamos que un agente está tratando de maximizar sus ganancias en el mercado de valores. La métrica de desempeño} \\ \textrm{solo considera las ganancias o pérdidas durante las primeras 𝑇 unidades de tiempo, y no tiene en cuenta el desempeño fu-} \\ \textrm{turo. En este caso, el agente puede adoptar una estrategia de alto riesgo y alta recompensa que tiene el potencial de generar} \\ \textrm{ganancias significativas a corto plazo, pero también puede llevar a pérdidas importantes a largo plazo. La racionalidad del} \\ \textrm{agente eneste escenario dependerá del tiempo disponible: si el agente tiene un horizonte de tiempo limitado (𝑇 es pequeño),} \\ \textrm{puede optar por esta estrategia de alto riesgo para maximizar su métrica de desempeño a corto plazo, aunque no sea una} \\ \textrm{elección prudente a largo plazo.}$
#
# - **$\textrm{Ejemplo 2: Agricultura intensiva y agotamiento de recursos}$**
#
# >$\textrm{Imaginemos un escenario en el que un agricultor tiene que tomar decisiones sobre el uso de fertilizantes y métodos de cultivo } \\ \textrm{para maximizar el rendimiento de sus cultivos en las primeras 𝑇 unidades de tiempo. Si la métrica de desempeño se centra} \\ \textrm{únicamente en el rendimiento a corto plazo, el agricultor podría optar por prácticas de agricultura intensiva que generen altos} \\ \textrm{rendimientos inmediatos, pero que también agoten los recursos del suelo y tengan un impacto negativo en la calidad del suelo} \\ \textrm{a largo plazo. En este caso, la racionalidad del agricultor dependerá del tiempo disponible: si el agricultor está enfocado en ma-} \\ \textrm{ximizar el rendimiento a corto plazo (𝑇 es pequeño), podría tomar decisiones que no sean sostenibles a largo plazo.}$

# %% [markdown]
# #### __3. `(1.0 puntos)` Para cada uno de los siguientes problemas, especifique los elementos PEAS.  No olvide mencionar todas las propiedades del ambiente.__
#
# *	Jugar baloncesto
# *	Explorar la superficie de la luna
# *	Comprar una obra de arte en una subasta
# *	Jugar poker
# *	ChatBot para una mesa de ayuda.
# * Jugar Ajedrez

# %% [markdown]
# **$\textrm{Jugar baloncesto:}$**
#
# * $\textrm{Rendimiento (Performance): El rendimiento se mide mediante el puntaje del juego, la precisión de los tiros, las asistencias, los} \\ \textrm{rebotes y la eficacia defensiva. El resultado del juego, ya sea victoria o derrota, también contribuye a la medida de rendimiento.} \\ $
# * $\textrm{Entorno (Environment): El entorno comprende la cancha de baloncesto, los jugadores, el balón, el marcador, el tiempo del juego } \\ \textrm{y las reglas del baloncesto que rigen la competición.} \\ $
# * $\textrm{Actuadores (Actuators): Los actuadores son los movimientos realizados por los jugadores, incluyendo pases, tiros al aro y dribbling,} \\ \textrm{que afectan la dinámica del juego.} \\ $
# * $\textrm{Sensores (Sensors): Los sensores captan información visual sobre la cancha, la posición de los jugadores y el balón, el tiempo restante  } \\ \textrm{en el juego y el puntaje actual.} \\ $
#
# **$\textrm{Explorar la superficie de la luna:}$**
#
# * $\textrm{Rendimiento (Performance): La medida de rendimiento abarca la distancia recorrida, las muestras recolectadas, la eficiencia de  } \\ \textrm{energía en el vehículo lunar, la habilidad para evitar obstáculos y la adquisición exitosa de datos científicos.} \\ $
# * $\textrm{Entorno (Environment): El entorno consiste en la superficie lunar con su terreno, rocas, cráteres, fluctuaciones de temperatura} \\ \textrm{y radiación. También incluye el vehículo lunar utilizado para la exploración.} \\ $
# * $\textrm{Actuadores (Actuators): Los actuadores son los motores del vehículo lunar y los brazos robóticos empleados para la recolección} \\ \textrm{de muestras y la interacción con el terreno lunar.} \\ $
# * $\textrm{Sensores (Sensors): Los sensores incluyen cámaras para capturar imágenes, sensores térmicos para medir la temperatura, sensores} \\ \textrm{de radiación y sensores de distancia para evitar obstáculos.} \\ $
#
# **$\textrm{Comprar una obra de arte en una subasta:}$**
#
# * $\textrm{Rendimiento (Performance): La medida de rendimiento implica la adquisición exitosa de la obra de arte deseada al mejor precio} \\ \textrm{posible, considerando el precio pagado y la competencia en la subasta.} \\ $
# * $\textrm{Entorno (Environment): El entorno comprende la sala de subastas, las obras de arte en exhibición, los pujadores, el subastador,} \\ \textrm{el precio inicial y las ofertas actuales.} \\ $
# * $\textrm{Actuadores (Actuators): Los actuadores consisten en las ofertas realizadas por el participante en la subasta y las señales para pu-} \\ \textrm{jar, que influyen en el proceso de adquisición.} \\ $
# * $\textrm{Sensores (Sensors): Los sensores detectan el precio actual de la obra de arte, las ofertas realizadas por otros pujadores y los comen-} \\ \textrm{tarios proporcionados por el subastador.} \\ $
#
# **$\textrm{Jugar poker:}$**
#
# * $\textrm{Rendimiento (Performance): La medida de rendimiento abarca las ganancias monetarias a largo plazo, la acumulación de fichas y} \\ \textrm{la habilidad para leer las estrategias de los oponentes.} \\ $
# * $\textrm{Entorno (Environment): El entorno consiste en la mesa de poker, las cartas, las fichas, los oponentes y las reglas del juego de poker.} \\ $
# * $\textrm{Actuadores (Actuators): Los actuadores son las acciones de apostar, retirarse, igualar o subir la apuesta, que el jugador emplea para} \\ \textrm{influir en el desarrollo de la partida.} \\ $
# * $\textrm{Sensores (Sensors):  Los sensores captan las cartas propias, las cartas comunitarias, las apuestas de los oponentes y el comportamiento} \\ \textrm{observable de los oponentes durante la partida.} \\ $
#
# **$\textrm{ChatBot para una mesa de ayuda:}$**
#
# * $\textrm{Rendimiento (Performance):  La medida de rendimiento se basa en la capacidad del ChatBot para proporcionar respuestas efectivas} \\ \textrm{y precisas a las consultas de los usuarios, asegurando la resolución exitosa de problemas y la satisfacción del usuario en un tiempo razonable.} \\ $
# * $\textrm{Entorno (Environment): El entorno incluye la plataforma de ayuda, las consultas planteadas por los usuarios, la base de conocimien-} \\ \textrm{tos disponible y las preguntas frecuentes.} \\ $
# * $\textrm{Actuadores (Actuators):  Los actuadores comprenden las respuestas generadas en formato de texto, la provisión de enlaces a recursos} \\ \textrm{relevantes y la posibilidad de derivar las consultas a expertos humanos si es necesario.} \\ $
# * $\textrm{Sensores (Sensors): Los sensores detectan las consultas de los usuarios, el contexto de la conversación y cualquier retroalimentación} \\ \textrm{proporcionada por los usuarios para mejorar la calidad de las respuestas brindadas.} \\ $
#
# **$\textrm{Jugar Ajedrez:}$**
#
# * $\textrm{Rendimiento (Performance):  La medida de rendimiento implica lograr la victoria en la partida a través de la obtención de un "mate"} \\ \textrm{en el rey del oponente, la realización de movimientos estratégicos y la construcción de una posición favorable en el tablero.} \\ $
# * $\textrm{Entorno (Environment): El entorno se compone del tablero de ajedrez, las piezas, las reglas del ajedrez y el oponente que juega en} \\ \textrm{un formato de turno por turno.} \\ $
# * $\textrm{Actuadores (Actuators):  Los actuadores son los movimientos de las piezas de ajedrez, que el jugador realiza de acuerdo con las reglas} \\ \textrm{del juego y en función de su estrategia.} \\ $
# * $\textrm{Sensores (Sensors): Los sensores detectan el estado actual del tablero de ajedrez, los movimientos realizados por el oponente y las re-} \\ \textrm{glas aplicables para determinar la validez de los movimientos.} \\ $

# %% [markdown]
# # __Robot Aspiradora__
#
# Los siguientes dos puntos utilizan el siguiente código como base.
#
# * Clase `Tablero`:
# * Clase `Agente`:
#
# Modifique las clases según lo considere necesario para cumplir los requerimientos de la simulación solicitada.

# %%
import random
import matplotlib.pyplot as plt

# %%
from IPython.display import display
import ipywidgets as widgets
import time

class Tablero:
  def __init__(self, tamano_celda=(50, 50), n_celdas=(5,5)):
    self.out = widgets.HTML()
    display(self.out)
    self.tamano_celda = tamano_celda
    self.n_celdas = n_celdas

  def dibujar(self, objetos):
    tablero = "<table border='1' >{}</table>"
    filas = ""

    for i in range(self.n_celdas[0]):
      s = ""
      for j in range(self.n_celdas[1]):
        contenido =""
        for o in objetos:
          if o.x == j and o.y == i:
            contenido = \
            "<div style='transform: rotate({angulo}deg);font-size:{tamano_emoticon}px;'>{emoticon}</div>".\
            format(angulo = o.angulo, tamano_emoticon = o.tamano_emoticon, emoticon = o.emoticon)
        s += "<td style='height:{alto}px;width:{ancho}px'>{contenido}</td>".\
          format(alto = self.tamano_celda[0], ancho = self.tamano_celda[1],
                contenido = contenido)
      filas += "<tr>{}</tr>".format(s)
    tablero = tablero.format(filas)
    self.out.value = tablero

# %%
class Agente:
  def __init__(self, x=0, y=0, angulo=0, emoticon="🤖", tamano_emoticon=30):
    self.x = x
    self.y = y
    self.angulo = angulo
    self.emoticon = emoticon
    self.tamano_emoticon = tamano_emoticon

# %% [markdown]
# #### __4. `(1.5 puntos)` Implemente una simulación para el problema del robot aspiradora presentado en clase. La simulación debe cumplir las siguientes especificaciones:__
#
#   * El agente aspiradora puede percibir las hojas en cualquiera de las 4 casillas adyacentes (N, S, W, E).
#   * El agente puede percibir los muros del tablero
#   * El agente aspiradora dispondrá de 6 acciones:  moverse a cualquiera de las 4 casillas adyacentes (N, S, W, E), aspirar o no realizar ninguna acción.
#   * El agente obtendrá un punto por cada cuadrado que se limpie.
#   * La posición inicial de la aspiradora deberá generarse de manera aleatoria en el tablero.
#   * La aspiradora solo tiene energía para realizar 100 movimientos. Las acciones de aspirar y percibir las hojas no consumen energía.
#   * El tablero debe tener un tamaño de 5 x 5.
#   * Se deben ubicar 10 hojas de manera aleatoria en el tablero.
#
# __Utilizando los parámetros mencionados:__
#
#   * Genere un comportamiento reflejo que maximice el puntaje obtenido por la aspiradora. Describa la estrategia utilizada.
#   * Realice 50 simulaciones con el comportamiento diseñado y realice un histograma con los puntajes obtenidos.
#   * ¿Es posible construir un agente racional que soluciones este problema únicamente con comportamientos reflejos?

# %%
class Aspiradora(Agente):
  def __init__(self, x=0, y=0, angulo=0, emoticon="🤖", tamano_emoticon=30, energia = 5):
    super().__init__(x, y, angulo, emoticon, tamano_emoticon)
    self.energia = energia
    self.puntaje = 0

  #Movimiento
  def abajo(self):
    if self.y < 4:
      self.y += 1
      self.energia -=1

  def derecha(self):
    if self.x < 4:
      self.x += 1
      self.energia -=1

  def arriba(self):
    if self.y > 0:
      self.y -= 1
      self.energia -=1

  def izquierda(self):
    if self.x > 0:
      self.x -= 1
      self.energia -=1


  def aspirar(self, hoja, objetos):
    if self.x == hoja.x and self.y == hoja.y:
      objetos.remove(hoja)
      self.puntaje += 1

  def escogerMovimiento(self):
  # Esquinas
    if self.x == 0 and self.y == 0:
      return random.choice(["derecha", "abajo"])
    elif self.x == 4 and self.y == 0:
      return random.choice(["izquierda", "abajo"])
    elif self.x == 0 and self.y == 4:
      return random.choice(["derecha", "arriba"])
    elif self.x == 4 and self.y == 4:
      return random.choice(["izquierda", "arriba"])

    # Laterales
    elif self.x == 0 and 0 < self.y < 4:
      return random.choice(["derecha", "abajo", "izquierda"])
    elif self.y == 0 and self.x < 0 and self.x < 4:
      return random.choice(["derecha", "abajo", "arriba"])
    elif self.x == 4 and 0 < self.y < 4:
      return random.choice(["izquierda", "derecha", "arriba"])
    elif self.y ==4  and self.x > 0 and self.x < 4:
      return random.choice(["izquierda", "abajo", "arriba"])

    # Centro (permite moverse en todas las direcciones)
    else:
      return random.choice(["izquierda", "derecha", "abajo", "arriba"])

  def mover(self):
    direccion_elegida = self.escogerMovimiento()

    if direccion_elegida == "abajo":
      self.abajo()
    elif direccion_elegida == "derecha":
      self.derecha()
    elif direccion_elegida == "arriba":
      self.arriba()
    elif direccion_elegida == "izquierda":
      self.izquierda()

  #Revisar hojas
  def percibirHojas(self, hojas):
    cuadros_adyacentes = []

    # Coordenadas de los cuadros adyacentes (Norte, Sur, Oeste, Este)
    adyacentes_coords = [(self.x, self.y - 1), (self.x, self.y + 1),
                         (self.x - 1, self.y), (self.x + 1, self.y)]

    for hoja in hojas:
        if (hoja.x,hoja.y) in adyacentes_coords:
            cuadros_adyacentes.append(hoja)

    return cuadros_adyacentes


  def accion(self, objetos):
    env = self.percibirHojas(objetos)
    hojas = self.percibirHojas(env)
    if hojas:
      hoja_destino = random.choice(hojas)
      x_destino, y_destino = hoja_destino.x, hoja_destino.y

      if x_destino < self.x:
          self.izquierda()
          self.aspirar(hoja_destino, objetos)
      elif x_destino > self.x:
          self.derecha()
          self.aspirar(hoja_destino, objetos)
      elif y_destino < self.y:
          self.arriba()
          self.aspirar(hoja_destino, objetos)
      elif y_destino > self.y:
          self.abajo()
          self.aspirar(hoja_destino, objetos)
    else:
      self.mover()

# %%
# Crear la lista de puntajes
puntajes = []

# Realizar 50 simulaciones
for rep in range(50):
    aspiradora = Aspiradora(x=random.randint(0, 4), y=random.randint(0, 4), energia=100)
    tablero = Tablero(n_celdas=(5, 5))
    numHojas = 10

    objetos = [aspiradora]

    for _ in range(numHojas):
        while True:
            x = random.randint(0, 4)
            y = random.randint(0, 4)
            if not any(agente.x == x and agente.y == y for agente in objetos):
                break
        agente = Agente(x=x, y=y, angulo=0, emoticon="🍂", tamano_emoticon=30)
        objetos.append(agente)

    while aspiradora.energia >= 0:
        #tablero.dibujar(objetos)
        time.sleep(0.01)
        aspiradora.accion(objetos)

    puntajes.append(aspiradora.puntaje)

# Crear el histograma
plt.hist(puntajes, bins=range(max(puntajes)+2), align='left')
plt.xlabel('Puntaje')
plt.ylabel('Frecuencia')
plt.title('Histograma del puntaje obtenido en 50 simulaciones')
plt.xticks(range(max(puntajes)+1))
plt.show()
# Out:
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')

# %% [markdown]
# - $\textrm{La estrategia utilizada por el agente aspiradora es un comportamiento reflejo reactivo simple. El agente aspiradora} \\ \textrm{toma decisiones basadas en la información inmediata disponible: su ubicación actual en el tablero y las hojas adya-} \\ \textrm{centes. Se mueve hacia las hojas adyacentes para aspirarlas y ganar puntos, y también puede moverse aleatoriamente} \\ \textrm{si no hay hojas adyacentes.} \\ $
#
# - $\textrm{En este caso, parece que un agente puramente reactivo no puede ser completamente racional para resolver el problema.} \\ \textrm{Dado que el agente solo puede percibir hojas adyacentes y no tiene capacidad para planificar acciones más allá de las in-} \\ \textrm{mediatas, es posible que no maximice su puntaje de manera consistente. } \\ $

# %% [markdown]
# #### __5. (1.5 puntos) Implemente una simulación para el problema del robot aspiradora presentado en clase. La simulación debe cumplir las siguientes especificaciones:__
#
#   * El agente aspiradora puede percibir las hojas en cualquiera de las 8 casillas adyacentes (se incluyen las diagonales).
#   * El agente puede percibir los muros del tablero
#   * El agente aspiradora dispondrá de 10 acciones:  moverse a cualquiera de las 8 casillas adyacentes aspirar o no realizar ningúna acción.
#   * El agente obtendrá un punto por cada cuadrado que se límpie.
#   * La posición inicial de la aspiradora deberá generarse de manera aleatoria en el tablero.
#   * La aspiradora solo tiene energía para realizar 200 acciones. La acciones de aspirar y percipir las hojas no consumen energía.
#   * El tablero debe tener un tamaño de 10 x 10.
#   * Se deben ubicar 50 hojas de manera aleatoria en el tablero.
#
# __Utilizando los parámetros mencionados:__
#
#   * Genere un comportamiento basado en estado que maximice el puntaje obtenido por la aspiradora. Describa la estrategia utilizada.
#   * Realice 50 simulaciones con el comportamiento diseñado y realice un histograma con los puntajes obtenidos.
#   * ¿Es posible construir un agente racional que soluciones este problema mediante un comportamiento basado en estado?

# %%
class AspiradoraV2(Aspiradora):
  def __init__(self, x=0, y=0, angulo=0, emoticon="🤖", tamano_emoticon=30,
               energia = 5, estado = "centro"):
    super().__init__(x, y, angulo, emoticon, tamano_emoticon, energia)
    self.estado = estado
    self.energia = energia
    self.puntaje = 0

  #Movimiento
  def abajo(self):
    if self.y < 9:
      self.y += 1
      self.energia -=1

  def derecha(self):
    if self.x < 9:
      self.x += 1
      self.energia -=1

  def arriba(self):
    if self.y > 0:
      self.y -= 1
      self.energia -=1

  def izquierda(self):
    if self.x > 0:
      self.x -= 1
      self.energia -=1

  def diagonal_superior_izquierda(self):
    if self.x > 0 and self.y > 0:
        self.x -= 1
        self.y -= 1
        self.energia -=1

  def diagonal_superior_derecha(self):
    if self.x < 9 and self.y > 0:
        self.x += 1
        self.y -= 1
        self.energia -=1

  def diagonal_inferior_izquierda(self):
    if self.x > 0 and self.y < 9:
        self.x -= 1
        self.y += 1
        self.energia -=1

  def diagonal_inferior_derecha(self):
    if self.x < 9 and self.y < 9:
        self.x += 1
        self.y += 1
        self.energia -=1


  def aspirar(self, hoja, objetos):
    if self.x == hoja.x and self.y == hoja.y:
      objetos.remove(hoja)
      self.puntaje += 1

  def mover(self):
    if self.estado == "centro":
      self.mover_al_centro()
    elif self.estado == "aleatorio":
      direccion_elegida = self.escogerMovimiento()

      direcciones_validas = {
          "abajo": self.abajo,
          "derecha": self.derecha,
          "diagonal_inferior_izquierda": self.diagonal_inferior_izquierda,
          "diagonal_inferior_derecha": self.diagonal_inferior_derecha,
          "diagonal_superior_izquierda": self.diagonal_superior_izquierda,
          "diagonal_superior_derecha": self.diagonal_superior_derecha,
          "arriba": self.arriba,
          "izquierda": self.izquierda
      }

      if direccion_elegida in direcciones_validas:
          movimiento_seleccionado = direcciones_validas[direccion_elegida]
          movimiento_seleccionado()

  def mover_al_centro(self):
      centro_x = 4
      centro_y = 4

      if self.x == 4 and self.y == 4:
        self.estado = "aleatorio"

      if self.x < centro_x:
          if self.y > centro_y:
              self.diagonal_superior_derecha()
          elif self.y < centro_y:
              self.diagonal_inferior_derecha()
          else:
              self.derecha()
      elif self.x > centro_x:
          if self.y > centro_y:
              self.diagonal_superior_izquierda()
          elif self.y < centro_y:
              self.diagonal_inferior_izquierda()
          else:
              self.izquierda()
      else:
          if self.y > centro_y:
              self.arriba()
          elif self.y < centro_y:
              self.abajo()

  def escogerMovimiento(self):
  # Esquinas
    if self.x == 0 and self.y == 0:
      self.estado = "centro"
      return random.choice(["derecha", "abajo","diagonal_inferior_derecha"])
    elif self.x == 9 and self.y == 0:
      self.estado = "centro"
      return random.choice(["izquierda", "abajo","diagonal_inferior_izquierda"])
    elif self.x == 0 and self.y == 9:
      self.estado = "centro"
      return random.choice(["derecha", "arriba","diagonal_superior_derecha"])
    elif self.x == 9 and self.y == 9:
      self.estado = "centro"
      return random.choice(["izquierda", "arriba","diagonal_superior_izquierda"])

    # Laterales
    elif self.x == 0 and 0 < self.y < 9:
      self.estado = "centro"
      return random.choice(["derecha", "abajo", "izquierda","diagonal_superior_derecha","diagonal_inferior_derecha"])
    elif self.y == 0 and self.x < 0 and self.x < 9:
      self.estado = "centro"
      return random.choice(["derecha", "abajo", "arriba","diagonal_inferior_derecha","diagonal_inferior_izquierda"])
    elif self.x == 9 and 0 < self.y < 9:
      self.estado = "centro"
      return random.choice(["izquierda", "derecha", "arriba","diagonal_superior_derecha","diagonal_superior_izquierda"])
    elif self.y == 9  and self.x > 0 and self.x < 9:
      self.estado = "centro"
      return random.choice(["izquierda", "abajo", "arriba","diagonal_inferior_izquierda","diagonal_superior_izquierda"])

    # Centro (permite moverse en todas las direcciones)
    else:
      return random.choice(["izquierda", "derecha", "abajo", "arriba",
                            "diagonal_inferior_izquierda","diagonal_inferior_derecha",
                            "diagonal_superior_izquierda","diagonal_superior_derecha"])

  #Revisar hojas
  def percibirHojas(self, hojas):
    cuadros_adyacentes = []

    # Coordenadas de los cuadros adyacentes (Norte, Sur, Oeste, Este, diagonales)
    adyacentes_coords = [(self.x, self.y - 1), (self.x, self.y + 1),
                         (self.x - 1, self.y), (self.x + 1, self.y),
                         (self.x - 1 ,self.y + 1), (self.x + 1, self.y + 1 ),
                         (self.x - 1 , self.y -1), (self.x + 1, self.y -1)]

    for hoja in hojas:
        if (hoja.x,hoja.y) in adyacentes_coords:
            cuadros_adyacentes.append(hoja)

    return cuadros_adyacentes


  def accion(self, objetos):
    env = self.percibirHojas(objetos)
    hojas = self.percibirHojas(env)
    if hojas:
      hoja_destino = random.choice(hojas)
      x_destino, y_destino = hoja_destino.x, hoja_destino.y

      if x_destino > self.x and y_destino < self.y :
          self.diagonal_superior_derecha()
          self.aspirar(hoja_destino, objetos)

      elif x_destino < self.x and y_destino > self.y :
          self.diagonal_inferior_izquierda()
          self.aspirar(hoja_destino, objetos)

      elif x_destino < self.x and y_destino < self.y :
          self.diagonal_superior_izquierda()
          self.aspirar(hoja_destino, objetos)

      elif x_destino > self.x and y_destino > self.y :
          self.diagonal_inferior_derecha()
          self.aspirar(hoja_destino, objetos)

      elif x_destino < self.x:
          self.izquierda()
          self.aspirar(hoja_destino, objetos)

      elif x_destino > self.x:
          self.derecha()
          self.aspirar(hoja_destino, objetos)
      elif y_destino < self.y:
          self.arriba()
          self.aspirar(hoja_destino, objetos)
      elif y_destino > self.y:
          self.abajo()
          self.aspirar(hoja_destino, objetos)
    else:
      self.mover()

# %%
puntajes = []
for rep in range(50):
    aspiradora = AspiradoraV2(x=random.randint(0, 9), y=random.randint(0, 9), energia=200)
    tablero = Tablero(n_celdas=(10, 10))
    numHojas = 50

    objetos = [aspiradora]

    for _ in range(numHojas):
        while True:
            x = random.randint(0, 9)
            y = random.randint(0, 9)
            if not any(agente.x == x and agente.y == y for agente in objetos):
                break
        agente = Agente(x=x, y=y, angulo=0, emoticon="🍂", tamano_emoticon=30)
        objetos.append(agente)

    while aspiradora.energia >= 0:
        #tablero.dibujar(objetos)
        time.sleep(0.01)
        aspiradora.accion(objetos)
    puntajes.append(aspiradora.puntaje)

# Crear el histograma
plt.hist(puntajes, bins=range(max(puntajes)+2), align='left')
plt.xlabel('Puntaje')
plt.ylabel('Frecuencia')
plt.title('Histograma del puntaje obtenido en 50 simulaciones')
plt.show()
# Out:
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')

# %% [markdown]
# - $\textrm{En esta ocasión, la estrategia utilizada por el agente aspiradora en esta simulación es un comportamiento basado en} \\ \textrm{estado que busca maximizar el puntaje obtenido. El agente sigue dos estados principales: "centro" y "aleatorio". En} \\ \textrm{el estado "centro", la aspiradora se mueve hacia el centro del tablero. Una vez que llega al centro, cambia al estado} \\ \textrm{"aleatorio" y realiza movimientos aleatorios para buscar hojas adyacentes y aspirarlas.}$
#
# > $\textrm{En el estado "aleatorio", la aspiradora utiliza una estrategia de búsqueda para encontrar hojas adyacentes en las ocho} \\ \textrm{direcciones posibles (N, S, E, W, NE, NW, SE, SW). Si encuentra hojas, se mueve en la dirección correspondiente y as-} \\ \textrm{pira la hoja. Si no hay hojas adyacentes, realiza movimientos aleatorios para explorar y buscar más hojas.} \\ $
#
# - $\textrm{Un agente basado en estado puede ser más racional que uno reactivo. El comportamiento basado en estado mejora la} \\ \textrm{racionalidad, pero un agente verdaderamente racional consideraría una estrategia más compleja, con planificación a} \\ \textrm{largo plazo, para maximizar el puntaje. El comportamiento basado en estado no garantiza máxima racionalidad.} \\ $
